# %% [markdown]
# # Scraping weather data
# for Washington DC from the website https://www.wunderground.com/history/daily/us/dc/washington/KDCA  for the year 2017.

# %%
# Web-Scraping packages
from bs4 import BeautifulSoup
from selenium import webdriver

# Essential packages
import numpy as np
import pandas as pd
import time
import datetime
from datetimerange import DateTimeRange

# %%
# a function that open a page wait 5 sec (to ensure that needed data are laoded) then scrape needed data.
def render_page(url):

    driver = webdriver.Chrome()
    driver.get(url)
    time.sleep(5)
    r = driver.page_source
    driver.quit()
    return r

# %%
# our main scraping function
def scraper(page, dates):
    
    output = pd.DataFrame()
    fails = []
    
    
    for d in dates:
    
        try:
            url = str(str(page) + str(d))

            r = render_page(url)

            # Find needed data
            soup = BeautifulSoup(r, "html.parser")
            container = soup.find('lib-city-history-observation')
            check = container.find('tbody')

            # Creating holder dataframe
            data = pd.DataFrame(np.zeros((105,10)) ,columns=["Date","Temp", "Dew point", "Humidity", "Wind", "Wind speed", "Wind Gust", "Pressure", "Precip.","Condition"])

            # Filling the Datafram
            for row, c in enumerate(check.find_all('tr', class_='ng-star-inserted')):
                for col, i in enumerate(c.find_all('td', class_='ng-star-inserted')):
                    trial = i.text
                    trial = trial.strip('  ')
                    data.iloc[row,col] = trial
            
            # Drop the empty rows
            data= data.loc[data["Date"]!=0]

            # Adding the date to the time recorded in data["Date"] (data["Date"] only has time in it, So we need to add the date)
            data["Date"]=[d + " " + i for i in data["Date"]]

            # Appending the data of each day to our output
            output = pd.concat([output, data], ignore_index=True)
            
        except:
            fails.append(d)

    return(output, fails)

# %%
# Creating a list of dates from 2017-01-01 to 2017-12-31

a = DateTimeRange("2017-1-1",'2017-12-31').range(datetime.timedelta(days=1))
c= list(a)
dates = []
for i in c:
    dates.append(str(i.date()))

dates
# Out:
# ['2017-01-01',
#  '2017-01-02',
#  '2017-01-03',
#  '2017-01-04',
#  '2017-01-05',
#  '2017-01-06',
#  '2017-01-07',
#  '2017-01-08',
#  '2017-01-09',
#  '2017-01-10',
#  '2017-01-11',
#  '2017-01-12',
#  '2017-01-13',
#  '2017-01-14',
#  '2017-01-15',
#  '2017-01-16',
#  '2017-01-17',
#  '2017-01-18',
#  '2017-01-19',
#  '2017-01-20',
#  '2017-01-21',
#  '2017-01-22',
#  '2017-01-23',
#  '2017-01-24',
#  '2017-01-25',
#  '2017-01-26',
#  '2017-01-27',
#  '2017-01-28',
#  '2017-01-29',
#  '2017-01-30',
#  '2017-01-31',
#  '2017-02-01',
#  '2017-02-02',
#  '2017-02-03',
#  '2017-02-04',
#  '2017-02-05',
#  '2017-02-06',
#  '2017-02-07',
#  '2017-02-08',
#  '2017-02-09',
#  '2017-02-10',
#  '2017-02-11',
#  '2017-02-12',
#  '2017-02-13',
#  '2017-02-14',
#  '2017-02-15',
#  '2017-02-16',
#  '2017-02-17',
#  '2017-02-18',
#  '2017-02-19',
#  '2017-02-20',
#  '2017-02-21',
#  '2017-02-22',
#  '2017-02-23',
#  '2017-02-24',
#  '2017-02-25',
#  '2017-02-26',
#  '2017-02-27',
#  '2017-02-28',
#  '2017-03-01',
#  '2017-03-02',
#  '2017-03-03',
#  '2017-03-04',
#  '2017-03-05',
#  '2017-03-06',
#  '2017-12-25',
#  '2017-12-26',
#  '2017-12-27',
#  '2017-12-28',
#  '2017-12-29',
#  '2017-12-30',
#  '2017-12-31']

# %%
# scraping round 1
weather, fails = scraper("https://www.wunderground.com/history/daily/us/va/arlington/KDCA/date/", dates=dates)
weather
# Out:
#                       Date   Temp Dew point Humidity Wind Wind speed  \
# 0      2017-01-01 12:52 AM  46ʡF     22ʡF    39ʡ%   SW     9ʡmph
# 1       2017-01-01 1:52 AM  44ʡF     22ʡF    42ʡ%  SSW     9ʡmph
# 2       2017-01-01 2:52 AM  43ʡF     23ʡF    45ʡ%  SSW    13ʡmph
# 3       2017-01-01 3:52 AM  41ʡF     23ʡF    49ʡ%   SW     5ʡmph
# 4       2017-01-01 4:52 AM  40ʡF     23ʡF    51ʡ%  SSW     5ʡmph
# ...                    ...    ...       ...      ...  ...        ...
# 10361   2017-12-31 7:52 PM  19ʡF      4ʡF    52ʡ%   NW    10ʡmph
# 10362   2017-12-31 8:52 PM  18ʡF      4ʡF    54ʡ%  NNW     8ʡmph
# 10363   2017-12-31 9:52 PM  17ʡF      2ʡF    52ʡ%  NNW    10ʡmph
# 10364  2017-12-31 10:52 PM  17ʡF      2ʡF    52ʡ%  NNW     8ʡmph
# 10365  2017-12-31 11:52 PM  17ʡF      2ʡF    52ʡ%  NNW    14ʡmph
#
#       Wind Gust   Pressure  Precip.      Condetion
# 0        0ʡmph  29.97ʡin  0.0ʡin  Mostly Cloudy
# 1        0ʡmph  29.98ʡin  0.0ʡin  Partly Cloudy
# 2        0ʡmph  30.00ʡin  0.0ʡin  Partly Cloudy
# 3        0ʡmph  30.02ʡin  0.0ʡin  Partly Cloudy
# 4        0ʡmph  30.04ʡin  0.0ʡin  Partly Cloudy
# ...         ...        ...      ...            ...
# 10361    0ʡmph  30.40ʡin  0.0ʡin           Fair
# 10362    0ʡmph  30.41ʡin  0.0ʡin           Fair
# 10363    0ʡmph  30.41ʡin  0.0ʡin           Fair
# 10364    0ʡmph  30.42ʡin  0.0ʡin           Fair
# 10365    0ʡmph  30.43ʡin  0.0ʡin           Fair
#
# [10366 rows x 10 columns]

# %%
len(fails)
# Out:
# 18

# %%
# Scraping round 2
w1 , f1 = scraper("https://www.wunderground.com/history/daily/us/va/arlington/KDCA/date/", dates= fails)
w1, len(f1)
# Out:
# (                    Date   Temp Dew point Humidity  Wind Wind speed Wind Gust  \
#  0    2017-02-21 12:52 AM  50ʡF     25ʡF    38ʡ%   ENE     5ʡmph    0ʡmph
#  1     2017-02-21 1:52 AM  48ʡF     24ʡF    39ʡ%   ENE     8ʡmph    0ʡmph
#  2     2017-02-21 2:52 AM  46ʡF     22ʡF    39ʡ%     E     8ʡmph    0ʡmph
#  3     2017-02-21 3:52 AM  45ʡF     25ʡF    46ʡ%     E     6ʡmph    0ʡmph
#  4     2017-02-21 4:52 AM  43ʡF     24ʡF    47ʡ%  CALM     0ʡmph    0ʡmph
#  ..                   ...    ...       ...      ...   ...        ...       ...
#  580   2017-12-20 7:52 PM  44ʡF     23ʡF    43ʡ%     N     6ʡmph    0ʡmph
#  581   2017-12-20 8:52 PM  41ʡF     28ʡF    60ʡ%   SSE     3ʡmph    0ʡmph
#  582   2017-12-20 9:52 PM  40ʡF     21ʡF    47ʡ%     N     8ʡmph    0ʡmph
#  583  2017-12-20 10:52 PM  40ʡF     25ʡF    55ʡ%     E     3ʡmph    0ʡmph
#  584  2017-12-20 11:52 PM  39ʡF     24ʡF    55ʡ%     E     3ʡmph    0ʡmph
#
#        Pressure  Precip.      Condetion
#  0    30.30ʡin  0.0ʡin         Cloudy
#  1    30.31ʡin  0.0ʡin  Mostly Cloudy
#  2    30.32ʡin  0.0ʡin         Cloudy
#  3    30.32ʡin  0.0ʡin         Cloudy
#  4    30.34ʡin  0.0ʡin         Cloudy
#  ..         ...      ...            ...
#  580  30.02ʡin  0.0ʡin           Fair
#  581  30.04ʡin  0.0ʡin           Fair
#  582  30.05ʡin  0.0ʡin           Fair
#  583  30.05ʡin  0.0ʡin           Fair
#  584  30.06ʡin  0.0ʡin           Fair
#
#  [585 rows x 10 columns],
#  0)

# %%
# final scraping result
weather = pd.concat([weather, w1], ignore_index=True)
weather.head()
# Out:
#                   Date   Temp Dew point Humidity Wind Wind speed Wind Gust  \
# 0  2017-01-01 12:52 AM  46ʡF     22ʡF    39ʡ%   SW     9ʡmph    0ʡmph
# 1   2017-01-01 1:52 AM  44ʡF     22ʡF    42ʡ%  SSW     9ʡmph    0ʡmph
# 2   2017-01-01 2:52 AM  43ʡF     23ʡF    45ʡ%  SSW    13ʡmph    0ʡmph
# 3   2017-01-01 3:52 AM  41ʡF     23ʡF    49ʡ%   SW     5ʡmph    0ʡmph
# 4   2017-01-01 4:52 AM  40ʡF     23ʡF    51ʡ%  SSW     5ʡmph    0ʡmph
#
#     Pressure  Precip.      Condetion
# 0  29.97ʡin  0.0ʡin  Mostly Cloudy
# 1  29.98ʡin  0.0ʡin  Partly Cloudy
# 2  30.00ʡin  0.0ʡin  Partly Cloudy
# 3  30.02ʡin  0.0ʡin  Partly Cloudy
# 4  30.04ʡin  0.0ʡin  Partly Cloudy

# %%
# Creating a weather time-serise
weather["Date"] = pd.to_datetime(weather["Date"])
weather["Time"]=weather["Date"].apply(lambda a: a.time())


weather.head()
# Out:
#                  Date   Temp Dew point Humidity Wind Wind speed Wind Gust  \
# 0 2017-01-01 00:52:00  46ʡF     22ʡF    39ʡ%   SW     9ʡmph    0ʡmph
# 1 2017-01-01 01:52:00  44ʡF     22ʡF    42ʡ%  SSW     9ʡmph    0ʡmph
# 2 2017-01-01 02:52:00  43ʡF     23ʡF    45ʡ%  SSW    13ʡmph    0ʡmph
# 3 2017-01-01 03:52:00  41ʡF     23ʡF    49ʡ%   SW     5ʡmph    0ʡmph
# 4 2017-01-01 04:52:00  40ʡF     23ʡF    51ʡ%  SSW     5ʡmph    0ʡmph
#
#     Pressure  Precip.      Condetion      Time
# 0  29.97ʡin  0.0ʡin  Mostly Cloudy  00:52:00
# 1  29.98ʡin  0.0ʡin  Partly Cloudy  01:52:00
# 2  30.00ʡin  0.0ʡin  Partly Cloudy  02:52:00
# 3  30.02ʡin  0.0ʡin  Partly Cloudy  03:52:00
# 4  30.04ʡin  0.0ʡin  Partly Cloudy  04:52:00

# %%
# Exporting the resultant data 
weather.to_csv("data/scraped_weather.csv")
